# %%
import pandas as pd
import os

# %%
#Import de librerias basicas tablas y matrices
import numpy as np 
import pandas as pd 

#Gradient Boosting
import lightgbm as lgb

#Funciones auxiliares sklearn
from sklearn.model_selection import train_test_split, StratifiedKFold #Split y cross Validation
from sklearn.metrics import cohen_kappa_score, accuracy_score, balanced_accuracy_score #Metricas
#from sklearn.utils import shuffle
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import OrdinalEncoder
from sklearn.compose import ColumnTransformer
from sklearn import set_config


#Visualizacióon
from plotly import express as px

#Plot de matriz de confusion normalizada en actuals
#from utils import plot_confusion_matrix

import os

#Optimizacion de hiperparametros
#import optuna

#from optuna.artifacts import FileSystemArtifactStore, upload_artifact

#Guardado de objetos en archivos joblib

#from joblib import load, dump

# %%
pathdata='data/'
filename = 'sell-in.txt'

# Unir ruta completa
filepath = os.path.join(pathdata, filename)
sell = pd.read_csv(filepath, sep="\t")

# %%
#sell = pd.read_csv(filepath, sep="\s+", engine="python")

# %%
sell.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2945818 entries, 0 to 2945817
# Data columns (total 7 columns):
#  #   Column                 Dtype
# ---  ------                 -----
#  0   periodo                int64
#  1   customer_id            int64
#  2   product_id             int64
#  3   plan_precios_cuidados  int64
#  4   cust_request_qty       int64
#  5   cust_request_tn        float64
#  6   tn                     float64
# dtypes: float64(2), int64(5)
# memory usage: 157.3 MB

# %%
sell.describe()
# Out:
#             periodo   customer_id    product_id  plan_precios_cuidados  \
# count  2.945818e+06  2.945818e+06  2.945818e+06           2.945818e+06
# mean   2.018017e+05  1.017148e+04  2.042787e+04           1.155163e-02
# std    8.142115e+01  1.421467e+02  3.124612e+02           1.068559e-01
# min    2.017010e+05  1.000100e+04  2.000100e+04           0.000000e+00
# 25%    2.017090e+05  1.005300e+04  2.016100e+04           0.000000e+00
# 50%    2.018050e+05  1.013300e+04  2.036600e+04           0.000000e+00
# 75%    2.019030e+05  1.026700e+04  2.065400e+04           0.000000e+00
# max    2.019120e+05  1.063700e+04  2.129900e+04           1.000000e+00
#
#        cust_request_qty  cust_request_tn            tn
# count      2.945818e+06     2.945818e+06  2.945818e+06
# mean       2.148753e+00     4.593203e-01  4.497863e-01
# std        3.571552e+00     3.222836e+00  3.108355e+00
# min        1.000000e+00     1.000000e-04  1.000000e-04
# ...

# %%
sell.isnull().sum()
# Out:
# periodo                  0
# customer_id              0
# product_id               0
# plan_precios_cuidados    0
# cust_request_qty         0
# cust_request_tn          0
# tn                       0
# dtype: int64

# %% [markdown]
# plan_precios_cuidados 75% es 0 categorica?
# cust_resquest_qty y tn outliers y st grande con respecto a media

# %%
df=sell.copy()

# %%
df_agg = df.groupby(['periodo', 'product_id'], as_index=False).agg({
    'tn': 'sum'
})

# %%
df_agg['periodo'] = pd.to_datetime(df_agg['periodo'].astype(str), format='%Y%m')

# %%
import altair as alt

# %%
import altair as alt
print(alt.__version__)
# Out:
# 4.2.2

# %%
df_agg
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 df_agg
#
# NameError: name 'df_agg' is not defined

# %% [markdown]
# magicos = [ 20002, 20003, 20006, 20010, 20011, 20018, 20019, 20021,
#    20026, 20028, 20035, 20039, 20042, 20044, 20045, 20046,  20049,
#    20051, 20052, 20053, 20055, 20008, 20001, 20017, 20086, 20180,
#    20193, 20320, 20532, 20612, 20637, 20807, 20838
#  ]

# %% [markdown]
# 20004,20005,20007,20009,20012,20013,20014,20015,20016,20020,20022
# 20023,20024,20025,
# hasta aca
# 20027
#
# 20028
# 20029
# 20030
# 20031
# 20032
# 20033
# 20035
# 20037
# 20038
# 20039
# 20041
# 20042
# 20043
# 20044
# 20045
# 20046
# 20047
# 20049
# 20050
# 20051
# 20052
# 20053
# 20054
# 20055
# 20056
# 20057
# 20058
# 20059
# 20061
# 20062
# 20063
# 20065
# 20066
# 20067
# 20068
# 20069
# 20070
# 20071
# 20072
# 20073
# 20074
# 20075
# 20076
# 20077
# 20079
# 20080
# 20081
# 20082
# 20084
# 20085
# 20086
# 20087
# 20089
# 20090
# 20091
# 20092
# 20093
# 20094
# 20095
# 20096
# 20097
# 20099
# 20100
# 20101
# 20102
# 20103
# 20106
# 20107
# 20108
# 20109
# 20111
# 20112
# 20114
# 20116
# 20117
# 20118
# 20119
# 20120
# 20121
# 20122
# 20123
# 20124
# 20125
# 20126
# 20127
# 20129
# 20130
# 20132
# 20133
# 20134
# 20135
# 20137
# 20138
# 20139
# 20140
# 20142
# 20143
# 20144
# 20145
# 20146
# 20148
# 20150
# 20151
# 20152
# 20153
# 20155
# 20157
# 20158
# 20159
# 20160
# 20161
# 20162
# 20164
# 20166
# 20167
# 20168
# 20170
# 20174
# 20175
# 20176
# 20177
# 20179
# 20180
# 20181
# 20182
# 20183
# 20184
# 20187
# 20188
# 20189
# 20192
# 20193
# 20196
# 20197
# 20198
# 20200
# 20201
# 20202
# 20203
# 20205
# 20206
# 20207
# 20208
# 20209
# 20210
# 20211
# 20212
# 20213
# 20215
# 20216
# 20218
# 20219
# 20220
# 20222
# 20224
# 20225
# 20226
# 20227
# 20228
# 20230
# 20231
# 20232
# 20233
# 20234
# 20235
# 20236
# 20237
# 20238
# 20239
# 20240
# 20241
# 20242
# 20244
# 20246
# 20249
# 20251
# 20252
# 20253
# 20254
# 20255
# 20256
# 20257
# 20259
# 20261
# 20262
# 20263
# 20264
# 20265
# 20266
# 20267
# 20268
# 20269
# 20270
# 20271
# 20272
# 20273
# 20275
# 20276
# 20277
# 20278
# 20280
# 20281
# 20282
# 20283
# 20284
# 20285
# 20286
# 20288
# 20289
# 20290
# 20291
# 20292
# 20295
# 20296
# 20297
# 20298
# 20299
# 20300
# 20301
# 20302
# 20303
# 20304
# 20305
# 20306
# 20307
# 20309
# 20310
# 20311
# 20313
# 20314
# 20315
# 20316
# 20317
# 20319
# 20320
# 20321
# 20322
# 20323
# 20324
# 20325
# 20326
# 20327
# 20328
# 20329
# 20330
# 20332
# 20334
# 20335
# 20336
# 20337
# 20338
# 20340
# 20341
# 20342
# 20343
# 20344
# 20346
# 20348
# 20349
# 20350
# 20351
# 20352
# 20353
# 20354
# 20355
# 20356
# 20357
# 20358
# 20359
# 20361
# 20362
# 20364
# 20365
# 20366
# 20367
# 20368
# 20372
# 20375
# 20377
# 20378
# 20379
# 20380
# 20381
# 20382
# 20383
# 20384
# 20385
# 20386
# 20387
# 20388
# 20389
# 20390
# 20395
# 20396
# 20398
# 20400
# 20401
# 20402
# 20403
# 20404
# 20406
# 20407
# 20408
# 20409
# 20410
# 20411
# 20414
# 20415
# 20416
# 20417
# 20418
# 20419
# 20421
# 20422
# 20424
# 20426
# 20428
# 20429
# 20432
# 20433
# 20434
# 20438
# 20440
# 20442
# 20443
# 20447
# 20449
# 20450
# 20453
# 20456
# 20458
# 20459
# 20460
# 20463
# 20464
# 20465
# 20466
# 20469
# 20470
# 20473
# 20474
# 20476
# 20477
# 20478
# 20479
# 20480
# 20481
# 20482
# 20483
# 20484
# 20488
# 20490
# 20491
# 20495
# 20496
# 20497
# 20500
# 20502
# 20503
# 20505
# 20508
# 20509
# 20510
# 20513
# 20514
# 20517
# 20520
# 20521
# 20522
# 20523
# 20524
# 20525
# 20526
# 20527
# 20530
# 20531
# 20532
# 20536
# 20537
# 20538
# 20539
# 20540
# 20541
# 20542
# 20544
# 20547
# 20548
# 20549
# 20551
# 20552
# 20553
# 20555
# 20558
# 20559
# 20560
# 20561
# 20563
# 20565
# 20567
# 20568
# 20569
# 20570
# 20571
# 20572
# 20574
# 20575
# 20576
# 20577
# 20578
# 20579
# 20580
# 20583
# 20585
# 20586
# 20588
# 20589
# 20592
# 20593
# 20596
# 20597
# 20599
# 20600
# 20601
# 20602
# 20603
# 20604
# 20605
# 20606
# 20609
# 20611
# 20612
# 20614
# 20615
# 20617
# 20620
# 20621
# 20622
# 20623
# 20624
# 20627
# 20628
# 20629
# 20632
# 20633
# 20636
# 20637
# 20638
# 20639
# 20640
# 20641
# 20642
# 20644
# 20646
# 20647
# 20649
# 20651
# 20652
# 20653
# 20654
# 20655
# 20657
# 20658
# 20659
# 20660
# 20661
# 20662
# 20663
# 20664
# 20666
# 20667
# 20670
# 20672
# 20673
# 20674
# 20676
# 20677
# 20678
# 20679
# 20680
# 20681
# 20682
# 20684
# 20685
# 20686
# 20689
# 20691
# 20693
# 20694
# 20696
# 20697
# 20699
# 20700
# 20701
# 20702
# 20703
# 20705
# 20706
# 20708
# 20709
# 20711
# 20713
# 20714
# 20715
# 20719
# 20720
# 20721
# 20724
# 20729
# 20730
# 20732
# 20733
# 20735
# 20737
# 20739
# 20741
# 20742
# 20743
# 20744
# 20745
# 20746
# 20749
# 20750
# 20751
# 20754
# 20756
# 20757
# 20758
# 20759
# 20761
# 20762
# 20765
# 20768
# 20771
# 20772
# 20773
# 20774
# 20775
# 20777
# 20781
# 20783
# 20785
# 20786
# 20788
# 20789
# 20793
# 20795
# 20800
# 20801
# 20802
# 20803
# 20807
# 20809
# 20810
# 20811
# 20812
# 20815
# 20817
# 20818
# 20820
# 20822
# 20823
# 20824
# 20826
# 20827
# 20828
# 20830
# 20831
# 20832
# 20835
# 20838
# 20840
# 20843
# 20845
# 20846
# 20847
# 20849
# 20852
# 20853
# 20855
# 20859
# 20862
# 20863
# 20864
# 20865
# 20870
# 20877
# 20878
# 20879
# 20882
# 20883
# 20885
# 20886
# 20892
# 20894
# 20899
# 20901
# 20902
# 20904
# 20906
# 20907
# 20908
# 20910
# 20912
# 20913
# 20914
# 20917
# 20919
# 20920
# 20922
# 20924
# 20925
# 20927
# 20928
# 20931
# 20932
# 20933
# 20936
# 20937
# 20941
# 20942
# 20945
# 20946
# 20947
# 20948
# 20949
# 20951
# 20953
# 20956
# 20957
# 20961
# 20962
# 20965
# 20966
# 20967
# 20968
# 20970
# 20975
# 20976
# 20982
# 20985
# 20986
# 20987
# 20990
# 20991
# 20994
# 20995
# 20996
# 20997
# 21001
# 21003
# 21006
# 21007
# 21008
# 21014
# 21016
# 21022
# 21024
# 21027
# 21028
# 21032
# 21033
# 21034
# 21035
# 21037
# 21038
# 21039
# 21040
# 21042
# 21044
# 21048
# 21049
# 21055
# 21056
# 21057
# 21058
# 21064
# 21065
# 21073
# 21074
# 21077
# 21079
# 21080
# 21084
# 21086
# 21087
# 21088
# 21092
# 21093
# 21097
# 21099
# 21105
# 21109
# 21110
# 21111
# 21112
# 21114
# 21118
# 21119
# 21126
# 21129
# 21131
# 21135
# 21140
# 21142
# 21144
# 21146
# 21153
# 21154
# 21155
# 21157
# 21159
# 21163
# 21164
# 21167
# 21168
# 21170
# 21171
# 21176
# 21179
# 21180
# 21182
# 21184
# 21190
# 21191
# 21192
# 21194
# 21196
# 21200
# 21201
# 21202
# 21207
# 21209
# 21212
# 21214
# 21218
# 21222
# 21224
# 21226
# 21227
# 21233
# 21244
# 21245
# 21246
# 21248
# 21252
# 21256
# 21259
# 21262
# 21263
# 21265
# 21266
# 21267
# 21276

# %%
import altair as alt
import pandas as pd

alt.data_transformers.disable_max_rows()

# Paso 1: Prepara los datos
df_agg = df.groupby(['periodo', 'product_id'], as_index=False)['tn'].sum()
df_agg['periodo'] = pd.to_datetime(df_agg['periodo'].astype(str), format='%Y%m')

# Paso 2: Crear etiqueta bimestral (enero-febrero, marzo-abril, etc.)
df_agg['bimestre'] = df_agg['periodo'].dt.to_period('2M').dt.start_time

# Paso 3: Agregación por bimestre
df_bi = df_agg.groupby(['bimestre', 'product_id'], as_index=False)['tn'].sum()

# Paso 4: Parámetro interactivo
product_param = alt.param(
    name='product_id',
    bind=alt.binding_select(options=sorted(df_bi['product_id'].unique()), name='Producto: '),
    value=df_bi['product_id'].iloc[0]
)

# Paso 5: Gráfico
chart = alt.Chart(df_bi).mark_line().encode(
    x=alt.X('bimestre:T', axis=alt.Axis(format='%b %Y', title='Bimestre')),
    y='tn:Q',
    tooltip=['bimestre:T', 'tn', 'product_id']
).add_params(
    product_param
).transform_filter(
    'datum.product_id == product_id'
).properties(
    width=700,
    height=400,
    title='Serie de tn cada bimestre para producto seleccionado'
)

chart

# %%
chart = alt.Chart(df_bi).mark_line().encode(
    x=alt.X('bimestre:T', 
        axis=alt.Axis(format='%b %Y', title='Bimestre', tickCount="month"),
        timeUnit='yearmonth'  # fuerza que se vea cada mes/bimestre
    ),
    y='tn:Q',
    tooltip=['bimestre:T', 'tn', 'product_id']
).add_params(
    product_param
).transform_filter(
    'datum.product_id == product_id'
).properties(
    width=700,
    height=400,
    title='Serie de tn cada bimestre para producto seleccionado'
)

# %%
df_bi[df_bi['product_id'] == 20010]
# Out:
#         bimestre  product_id          tn
# 9     2017-01-01       20010   441.25546
# 794   2017-02-01       20010   562.98287
# 1575  2017-03-01       20010   718.44870
# 2361  2017-04-01       20010   607.72864
# 3145  2017-05-01       20010   759.99707
# 3951  2017-06-01       20010  1032.41184
# 4774  2017-07-01       20010   573.89415
# 5600  2017-08-01       20010   651.39113
# 6447  2017-09-01       20010   940.83230
# 7276  2017-10-01       20010  1212.23362
# 8125  2017-11-01       20010   747.14647
# 8985  2017-12-01       20010   507.57042
# 9841  2018-01-01       20010   298.25586
# 10695 2018-02-01       20010   477.48363
# 11543 2018-03-01       20010   653.77607
# 12396 2018-04-01       20010   171.74107
# 13250 2018-05-01       20010   227.24082
# 14114 2018-06-01       20010   223.87746
# 14965 2018-07-01       20010   331.96807
# 15811 2018-08-01       20010   582.83104
# 16659 2018-09-01       20010   480.60235
# 17534 2018-10-01       20010   612.50721
# ...

# %%
chart
# Out:
# alt.Chart(...)

# %% [markdown]
# El comportamiento de la serie afecta al modelo SARIMAX principalmente en su estacionariedad, estacionalidad, tendencia, y la calidad/relación de las variables exógenas. Por eso, es fundamental analizar bien la serie antes de modelarla: visualizarla, aplicar tests de Dickey-Fuller o KPSS, examinar autocorrelaciones y considerar transformaciones adecuadas.
#
# ¿Querés que analicemos un caso concreto o un dataset espe

# %%
[21249,
 21268,
 21273,
 21274,
 21275,
 21277,
 21278,
 21279,
 21281,
 21282,
 21283,
 21284,
 21285,
 21286,
 21287,
 21288,
 21289,
 21290,
 21291,
 21292,
 21293,
 21294,
 21295,
 21296,
 21297,
 21298,
 21299,
 21061,
 21066,
 21230,
 21106]

# %%
df_agg[df_agg['product_id'] == 20127]
# Out:
#          periodo  product_id         tn   bimestre
# 27614 2019-09-01       20127   12.80399 2019-09-01
# 28543 2019-10-01       20127  186.81735 2019-10-01
# 29494 2019-11-01       20127  463.80054 2019-11-01
# 30433 2019-12-01       20127  170.32792 2019-12-01

# %%
# Convertir a formato yyyymm entero
df_agg['periodo_ym'] = df_agg['periodo'].dt.year * 100 + df_agg['periodo'].dt.month

# Definir rango objetivo: septiembre a diciembre 2019
rango_objetivo = set([201909, 201910, 201911, 201912])

# Agrupar por producto, y recolectar los meses
periodos_por_producto = df_agg.groupby('product_id')['periodo_ym'].apply(set).reset_index()

# Filtrar productos que tienen exactamente esos 4 meses y nada más
productos_finales = periodos_por_producto[
    periodos_por_producto['periodo_ym'] == rango_objetivo
]['product_id'].tolist()

# %%
productos_finales
# Out:
# [20127, 20210, 20686, 20703, 20962, 20975, 20995, 21087, 21214]

# %%
periodos_por_producto
# Out:
#       product_id                                            periodo
# 0          20001  {2019-03-01 00:00:00, 2017-11-01 00:00:00, 201...
# 1          20002  {2019-03-01 00:00:00, 2017-11-01 00:00:00, 201...
# 2          20003  {2019-03-01 00:00:00, 2017-11-01 00:00:00, 201...
# 3          20004  {2019-03-01 00:00:00, 2017-11-01 00:00:00, 201...
# 4          20005  {2019-03-01 00:00:00, 2017-11-01 00:00:00, 201...
# ...          ...                                                ...
# 1228       21295                              {2017-01-01 00:00:00}
# 1229       21296                              {2017-08-01 00:00:00}
# 1230       21297                              {2017-01-01 00:00:00}
# 1231       21298                              {2017-08-01 00:00:00}
# 1232       21299                              {2017-08-01 00:00:00}
#
# [1233 rows x 2 columns]

# %%
#data\tb_productos.txt
pathdata='data/'
filename = 'tb_productos.txt'

# Unir ruta completa
filepath = os.path.join(pathdata, filename)
productos = pd.read_csv(filepath,sep="\t")

# %%
productos

# %%
completo=pd.merge(sell,productos,on='product_id',how='inner')

# %%
completo

# %%
df_agg = completo.groupby(['periodo', 'cat1'], as_index=False).agg({
    'tn': 'sum'
})

# %%
df_agg

# %%
df_agg['periodo'] = pd.to_datetime(df_agg['periodo'].astype(str), format='%Y%m')

# %%
df_agg.info()

# %%
import altair as alt

chart = alt.Chart(df_agg).mark_line().encode(
    x='periodo:T',
    y='tn:Q',
    color='cat1:N',
    tooltip=['periodo:T', 'cat1:N', 'tn:Q']
).properties(
    width=600,
    height=400,
    title='Series por cat1'
)

chart

# %%
df_agg = completo.groupby(['product_id'], as_index=False).agg({
    'tn': 'sum'
})

# %%
df_agg

# %%
df_ordenado = df_agg.sort_values(by='tn', ascending=False)

# %%
top50 = df_ordenado.head(50)
top50

# %%
df_agg = completo.groupby(['periodo', 'product_id','customer_id'], as_index=False).agg({
    'tn': 'sum'
})

# %%
df_agg['periodo'] = pd.to_datetime(df_agg['periodo'].astype(str), format='%Y%m')

# %%
df_agg.info()

# %%
df_filtrado = df_agg[df_agg['product_id'].isin(top50['product_id'])]

# %%
df_filtrado

# %%
import altair as alt
import pandas as pd

alt.data_transformers.disable_max_rows()

# Asegurate de que 'periodo' sea datetime (opcional pero recomendable)
#df_agg['periodo'] = pd.to_datetime(df_agg['periodo'].astype(str), format='%Y%m')

# Crear lista de opciones únicas para el selector
customer_options = sorted(df_filtrado['customer_id'].unique())

# Crear parámetro con menú desplegable
customer_param = alt.param(
    name='SeleccionCliente',
    bind=alt.binding_select(options=customer_options, name='Cliente: '),
    value=customer_options[0]  # valor inicial
)

# Crear gráfico filtrado por parámetro
chart = alt.Chart(df_filtrado).mark_line().encode(
    x='periodo:T',
    y='tn:Q',
    color='product_id:N',
    tooltip=['periodo:T', 'product_id:N', 'tn:Q']
).add_params(
    customer_param
).transform_filter(
    'customer_id == SeleccionCliente'
).properties(
    width=700,
    height=400,
    title='Consumo por cliente y producto en el tiempo'
)

chart
